# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import seaborn as sns
plt.rcParams['font.size'] = 16

data = pd.read_csv("singly_list.csv")
X_exp = data['N']
Y_exp = data.iloc[:,1:-1]

# params, covariance = curve_fit(lambda n,a : a*n**2, X_exp, Y_exp)
# X_fit = np.logspace(1, math.log(max(X_exp), 10), 100)
# Y_fit = X_fit**2 * params[0]

columns_to_plot = ["insert(ms)", "search(ms)", "removeFirst(ms)", "removeStart(ms)", "removeEnd(ms)"]

# Plot each column against N
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(data["N"], data[column]/data['reps'], 'o--', label=column)

# Add labels, title, and legend
plt.xlabel("N (Number of Elements)")
plt.ylabel("Time (ms)")
plt.title("Performance Metrics vs. N")
plt.legend()
plt.grid(True)
plt.show()

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import seaborn as sns
plt.rcParams['font.size'] = 16

data = pd.read_csv("min_heap.csv")
X_exp = data['N']
Y_exp = data.iloc[:,1:-1]

columns_to_plot = ["insert(ms)", "search(ms)", "removeRoot(ms)"]

# Plot each column against N
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(data["N"], data[column]/data['reps'], 'o--', label=column)

# Add labels, title, and legend
plt.xlabel("N (Number of Elements)")
plt.ylabel("Time (ms)")
plt.title("Performance Metrics of Min Heap")
plt.legend()
plt.grid(True)
plt.show()

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import seaborn as sns
plt.rcParams['font.size'] = 16

data = pd.read_csv("sort_merge_quick.csv")
X_exp = data['N']
Y_exp = data.iloc[:,1:-1]

columns_to_plot = ["quickrandom(ms)","mergebest(ms)","mergerandom(ms)","mergeworst(ms)"]

# Plot each column against N
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(data["N"], data[column], 'o--', label=column)

# Add labels, title, and legend
plt.xlabel("N (Number of Elements)")
plt.ylabel("Time (ms)")
plt.title("Performance Metrics of Sorts")
plt.legend()
plt.grid(True)
plt.show()
